# %% [markdown]
# # Image inverter
#
# Use `matplotlib.image` to read jpg images
#
# Use `matplotlib.pyplot` to show these images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# The following methods is used to make the conversion
#
# The `imread` method allows you to split an image into its RGB factors

# %%
image = mpimg.imread("foto2.jpg")
implot = plt.imshow(image)
plt.show()

# %% [markdown]
# Now, we will split this RGB factors and show them

# %%
# Split colors

type(image)
print(image.shape)

# r = [(d[0], 0, 0) for d in image]
# g = [(0, d[1], 0) for d in image]
# b = [(0, 0, d[2]) for d in image]

# plt.imshow(r)
# plt.show()
# Out:
# (800, 800, 3)
